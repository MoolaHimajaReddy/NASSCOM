# %%
#task 1.1
from datetime import datetime
import random

raw_sensor_data = []

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']

READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

for i in range(100):
    device_id = f"DEV{i+1:03}"

    timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)
    min_val, max_val = READING_RANGES[device_type]
    value = round(random.uniform(min_val, max_val), 2)

    reading = (timestamp, device_id, device_type, location, value)
    raw_sensor_data.append(reading)
for reading in raw_sensor_data:
    print(reading)

#task1.2

temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == 'Temperature_Sensor':
        timestamp = reading[0]
        device_id = reading[1]
        location = reading[3]
        temperature = reading[4]

        temp_dict = {
            'timestamp': timestamp,
            'device_id': device_id,
            'location': location,
            'temperature_celsius': temperature
        }

        temperature_readings.append(temp_dict)
for reading in temperature_readings:
  print(reading)

#task1.3

unique_locations = {reading[3] for reading in raw_sensor_data}
print(unique_locations)

#task1.4

device_stats = {}

for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]
    if device_type not in device_stats:
        device_stats[device_type] = (value, value)
    else:
        current_min, current_max = device_stats[device_type]
        new_min = min(current_min, value)
        new_max = max(current_max, value)
        device_stats[device_type] = (new_min, new_max)

print(device_stats)

#task1.5.1

sliced_readings_1 = raw_sensor_data[9:20]
sliced_readings_2 = raw_sensor_data[::5]
print(sliced_readings_2)

#task 1.5.2

sample_string = "Python Programming"
substring_1 = sample_string[7:19]
substring_2 = sample_string[5::-1]
print(substring_1)
print(substring_2)

#task 1.5.3

fifth_reading_device_type = raw_sensor_data[4][2]
device_type_suffix = fifth_reading_device_type[-6:]
print(fifth_reading_device_type)
print(device_type_suffix)

#task 2.1

def get_readings_by_location(readings_list, target_location):
  result = []

  for reading in readings_list:
    if reading[3] == target_location:
      result.append(reading)
  return(result)
filtered_readings = get_readings_by_location(raw_sensor_data, 'Lab1')
print(filtered_readings)

#task 2.2

def calculate_average_temperature(temp_data_list):
    total = 0
    count = 0

    for reading in temp_data_list:
        total += reading['temperature_celsius']
        count += 1

    if count == 0:
        return 0.0

    return total / count
avg_temp = calculate_average_temperature(temperature_readings)
print(avg_temp)

#task 2.3

def generate_report_line(reading_dict):
  return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"

for reading in temperature_readings:
    print(generate_report_line(reading))

#task 3.1

import os
reports_dir = 'sensor_reports'

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")

#task 3.2

from datetime import datetime

if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    date_format = '%Y-%m-%d %H:%M:%S'

    first_dt = datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days

    hours = duration.seconds // 3600
    minutes = (duration.seconds % 3600) // 60

    print(f"Duration: {days} days, {hours} hours, {minutes} minutes")

#task 3.3

import random

for i in range(5):
    num = random.randint(100, 200)
    print(num)

#task 4.1

import os

report_filename = os.path.join(reports_dir, 'temperature_report.txt')

try:
    with open(report_filename, 'w') as f:
        for reading in temperature_readings:
            f.write(generate_report_line(reading) + '\n')

    print(f"\nTemperature report written to '{report_filename}'.")

except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")

#task 4.2

import os

report_filename = os.path.join('sensor_reports', 'temperature_report.txt')

try:
    with open(report_filename, 'r') as f:
        read_report_lines = f.readlines()

    print("First 3 lines from the report:")
    for line in read_report_lines[:3]:
        print(line.strip())

except IOError as e:
    print(f"Error reading file '{report_filename}': {e}")
# Out:
# ('2026-08-13 09:10:48', 'DEV001', 'Pressure_Sensor', 'Lab2', 1024.82)
# ('2026-08-13 09:10:48', 'DEV002', 'Temperature_Sensor', 'Warehouse', 28.49)
# ('2026-08-13 09:10:48', 'DEV003', 'Light_Sensor', 'Lab1', 782.22)
# ('2026-08-13 09:10:48', 'DEV004', 'Pressure_Sensor', 'OfficeA', 992.93)
# ('2026-08-13 09:10:48', 'DEV005', 'Temperature_Sensor', 'Warehouse', 18.54)
# ('2026-08-13 09:10:48', 'DEV006', 'Temperature_Sensor', 'OfficeA', 26.03)
# ('2026-08-13 09:10:48', 'DEV007', 'Pressure_Sensor', 'Warehouse', 995.46)
# ('2026-08-13 09:10:48', 'DEV008', 'Light_Sensor', 'OfficeB', 374.19)
# ('2026-08-13 09:10:48', 'DEV009', 'Pressure_Sensor', 'OfficeA', 983.69)
# ('2026-08-13 09:10:48', 'DEV010', 'Light_Sensor', 'Warehouse', 703.39)
# ('2026-08-13 09:10:48', 'DEV011', 'Humidity_Sensor', 'OfficeB', 37.05)
# ('2026-08-13 09:10:48', 'DEV012', 'Humidity_Sensor', 'Warehouse', 59.57)
# ('2026-08-13 09:10:48', 'DEV013', 'Temperature_Sensor', 'Lab1', 29.74)
# ('2026-08-13 09:10:48', 'DEV014', 'Humidity_Sensor', 'Warehouse', 55.78)
# ('2026-08-13 09:10:48', 'DEV015', 'Light_Sensor', 'Warehouse', 333.82)
# ('2026-08-13 09:10:48', 'DEV016', 'Temperature_Sensor', 'OfficeA', 19.16)
# ('2026-08-13 09:10:48', 'DEV017', 'Temperature_Sensor', 'Lab1', 26.53)
# ('2026-08-13 09:10:48', 'DEV018', 'Humidity_Sensor', 'Warehouse', 56.7)
# ('2026-08-13 09:10:48', 'DEV019', 'Light_Sensor', 'OfficeA', 972.37)
# ('2026-08-13 09:10:48', 'DEV020', 'Pressure_Sensor', 'OfficeB', 984.0)
# ('2026-08-13 09:10:48', 'DEV021', 'Pressure_Sensor', 'Lab1', 1011.29)
# ('2026-08-13 09:10:48', 'DEV022', 'Temperature_Sensor', 'Lab1', 25.63)
# ('2026-08-13 09:10:48', 'DEV088', 'Humidity_Sensor', 'OfficeB', 50.65)
# ('2026-08-13 09:10:48', 'DEV089', 'Humidity_Sensor', 'OfficeA', 51.2)
# ('2026-08-13 09:10:48', 'DEV090', 'Temperature_Sensor', 'Lab1', 18.79)
# ('2026-08-13 09:10:48', 'DEV091', 'Temperature_Sensor', 'Warehouse', 27.39)
# ('2026-08-13 09:10:48', 'DEV092', 'Pressure_Sensor', 'Lab1', 1005.22)
# ('2026-08-13 09:10:48', 'DEV093', 'Pressure_Sensor', 'Lab1', 1024.47)
# ('2026-08-13 09:10:48', 'DEV094', 'Pressure_Sensor', 'OfficeA', 1014.34)
# ('2026-08-13 09:10:48', 'DEV095', 'Pressure_Sensor', 'OfficeB', 1009.55)
# ('2026-08-13 09:10:48', 'DEV096', 'Light_Sensor', 'Warehouse', 747.93)
# ('2026-08-13 09:10:48', 'DEV097', 'Temperature_Sensor', 'Lab1', 26.97)
# ('2026-08-13 09:10:48', 'DEV098', 'Humidity_Sensor', 'OfficeA', 58.31)
# ('2026-08-13 09:10:48', 'DEV099', 'Light_Sensor', 'Warehouse', 895.37)
# ('2026-08-13 09:10:48', 'DEV100', 'Temperature_Sensor', 'OfficeB', 22.39)
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV002', 'location': 'Warehouse', 'temperature_celsius': 28.49}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV005', 'location': 'Warehouse', 'temperature_celsius': 18.54}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV006', 'location': 'OfficeA', 'temperature_celsius': 26.03}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV013', 'location': 'Lab1', 'temperature_celsius': 29.74}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV016', 'location': 'OfficeA', 'temperature_celsius': 19.16}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV017', 'location': 'Lab1', 'temperature_celsius': 26.53}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV022', 'location': 'Lab1', 'temperature_celsius': 25.63}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV027', 'location': 'Lab1', 'temperature_celsius': 18.74}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV031', 'location': 'Lab2', 'temperature_celsius': 26.21}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV032', 'location': 'OfficeA', 'temperature_celsius': 19.94}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV035', 'location': 'OfficeA', 'temperature_celsius': 22.06}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV036', 'location': 'Lab1', 'temperature_celsius': 18.15}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV038', 'location': 'Lab2', 'temperature_celsius': 29.99}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV046', 'location': 'OfficeB', 'temperature_celsius': 27.73}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV048', 'location': 'OfficeA', 'temperature_celsius': 22.96}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV051', 'location': 'OfficeB', 'temperature_celsius': 27.33}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV066', 'location': 'Lab2', 'temperature_celsius': 24.63}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV072', 'location': 'Lab1', 'temperature_celsius': 29.19}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV073', 'location': 'Lab2', 'temperature_celsius': 23.7}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV075', 'location': 'OfficeA', 'temperature_celsius': 21.99}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV078', 'location': 'OfficeB', 'temperature_celsius': 28.32}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV082', 'location': 'OfficeA', 'temperature_celsius': 29.55}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV090', 'location': 'Lab1', 'temperature_celsius': 18.79}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV091', 'location': 'Warehouse', 'temperature_celsius': 27.39}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV097', 'location': 'Lab1', 'temperature_celsius': 26.97}
# {'timestamp': '2026-08-13 09:10:48', 'device_id': 'DEV100', 'location': 'OfficeB', 'temperature_celsius': 22.39}
# {'OfficeA', 'Warehouse', 'Lab1', 'OfficeB', 'Lab2'}
# {'Pressure_Sensor': (981.54, 1028.99), 'Temperature_Sensor': (18.15, 29.99), 'Light_Sensor': (138.79, 983.49), 'Humidity_Sensor': (31.19, 78.27)}
